# %% [markdown]
# Using the `all data` gdb of historical fires from Calfire:
# https://www.fire.ca.gov/what-we-do/fire-resource-assessment-program/fire-perimeters

# %%
import requests
import zipfile
import os
import fiona
import geopandas as gpd
import json
from shapely.geometry import mapping

import sys
sys.path.append("..")

from src.routers.dependencies import get_cloud_logger, get_cloud_static_io_client 

from dotenv import load_dotenv
load_dotenv("../.devcontainer/.env")

from google.cloud import tasks_v2
from google.protobuf import timestamp_pb2
import geopandas as gpd
import datetime
import json
from shapely.geometry import box
from src.routers.batch.batch_analyze_and_fetch import main as batch_analyze_and_fetch
from google.cloud import logging
from src.util.cloud_static_io import CloudStaticIOClient

# Extract zip file
with zipfile.ZipFile("fire221gdb.zip", "r") as zip_ref:
    zip_ref.extractall(".")

# Get the name of the gdb file
gdb_file = [f for f in os.listdir(".") if f.endswith(".gdb")][0]

# List all layers in the GDB file
layers = fiona.listlayers(gdb_file)

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# According to calfire:
#
# ```
# The fire perimeters database includes three layers—historical fire perimeters (firep), Rx treatments using fire (rxburn), and Rx treatments not using fire (Non_RXFire_Legacy).
# ```

# %%
layers
# Out:
# ['rxburn22_1', 'firep22_1', 'Non_RXFire_Legacy13_2']

# %%
rx_treatments_with_fire = gpd.read_file(gdb_file, layer=layers[0])
rx_treatments_without_fire = gpd.read_file(gdb_file, layer=layers[2])
fire_perimeters = gpd.read_file(gdb_file, layer=layers[1])

rx_treatments_with_fire.to_crs(epsg=4326, inplace=True)
rx_treatments_without_fire.to_crs(epsg=4326, inplace=True)
fire_perimeters.to_crs(epsg=4326, inplace=True)

# %%
rx_treatments_with_fire.head()
# Out:
#   YEAR_ STATE AGENCY UNIT_ID TREATMENT_ID         TREATMENT_NAME  \
# 0  2020    CA    CDF     AEU        10509  Jan 31 2020 Broadcast
# 1  2020    CA    PVT     AEU        10572   2020 Fuels Reduction
# 2  2020    CA    CDF     AEU        10630     Feb 2020 Broadcast
# 3  2020    CA    CDF     AEU        10639     Feb 2020 Broadcast
# 4  2020    CA    CDF     AEU        10780   Mar 3 2020 Broadcast
#
#                  START_DATE                   END_DATE  TREATED_AC  GIS_ACRES  \
# 0 2020-01-31 00:00:00+00:00  2020-01-31T00:00:00+00:00        15.0  15.047042
# 1 2020-02-13 00:00:00+00:00  2020-02-13T00:00:00+00:00        22.3  36.739700
# 2 2020-02-13 00:00:00+00:00  2020-02-18T00:00:00+00:00        22.4  38.839832
# 3 2020-02-11 00:00:00+00:00  2020-02-20T00:00:00+00:00        75.5  75.498100
# 4 2020-03-03 00:00:00+00:00  2020-03-03T00:00:00+00:00        61.8  61.771519
#
#    RX_CONSUM  PRE_CON_CLASS  POST_CON_CLASS  TREATMENT_TYPE  Shape_Length  \
# 0        NaN            NaN             NaN             1.0   1365.887529
# 1        NaN            NaN             NaN             1.0   2681.610336
# 2        NaN            NaN             NaN             1.0   3918.219956
# 3        NaN            NaN             NaN             1.0   3918.834462
# 4        NaN            NaN             NaN             1.0   2769.034316
#
#       Shape_Area                                           geometry
# 0   60893.216906  MULTIPOLYGON (((-120.52136 38.75171, -120.5212...
# 1  148680.293398  MULTIPOLYGON (((-120.66046 38.90069, -120.6605...
# 2  157179.228865  MULTIPOLYGON (((-120.57195 38.50208, -120.5718...
# 3  305529.980211  MULTIPOLYGON (((-120.54192 38.74314, -120.5419...
# 4  249980.461716  MULTIPOLYGON (((-120.54811 38.74108, -120.5481...

# %%
rx_treatments_without_fire.head()
# Out:
#   TREATMENT_ID                   TREATMENT_NAME  TREATMENT_TYPE UNIT_ID  \
# 0      3277604                          NON_WUI              13     SQF
# 1      3277608                          NON_WUI              15     SQF
# 2      3277612              SOUTHRIDGE 1-1 CHIP               5     BDF
# 3      3277613  SOUTHRIDGE UNIT 5 CUT AND STACK               9     BDF
# 4      3277840     HIGHWAY 20 CUT & PILING (06)               9     TNF
#
#   AGENCY  TREATED_AC   GIS_ACRES STATE YEAR_  RX_CONSUM  PRE_CON_CLASS  \
# 0    USF  136.388878  136.388840    CA  2006        NaN            NaN
# 1    USF  292.127163  292.126648    CA  2006        NaN            NaN
# 2    USF    4.726939    4.726954    CA  2006        NaN            NaN
# 3    USF   22.742776   22.742844    CA  2006        NaN            NaN
# 4    USF  106.348339  106.347382    CA  2006        NaN            NaN
#
#    POST_CON_CLASS                  END_DATE START_DATE  Shape_Length  \
# 0             NaN 2006-04-15 00:00:00+00:00        NaT   7391.270964
# 1             NaN 2006-07-03 00:00:00+00:00        NaT  17166.848106
# 2             NaN 2006-02-01 00:00:00+00:00        NaT    880.091816
# 3             NaN 2006-03-01 00:00:00+00:00        NaT   1623.896026
# 4             NaN 2006-09-15 00:00:00+00:00        NaT   3002.279795
#
#      Shape_Area                                           geometry
# 0  5.519460e+05  MULTIPOLYGON (((-118.50884 36.10266, -118.5086...
# 1  1.182195e+06  MULTIPOLYGON (((-118.96349 36.78626, -118.9632...
# 2  1.912930e+04  MULTIPOLYGON (((-116.69961 33.73683, -116.6997...
# 3  9.203702e+04  MULTIPOLYGON (((-116.70554 33.72558, -116.7052...
# 4  4.303726e+05  MULTIPOLYGON (((-120.79859 39.31701, -120.7983...

# %%
fire_perimeters.head()
# Out:
#   YEAR_ STATE AGENCY UNIT_ID FIRE_NAME   INC_NUM                 ALARM_DATE  \
# 0  2020    CA    CDF     NEU    NELSON  00013212  2020-06-18T00:00:00+00:00
# 1  2020    CA    CDF     NEU   AMORUSO  00011799  2020-06-01T00:00:00+00:00
# 2  2020    CA    CDF     NEU    ATHENS  00018493  2020-08-10T00:00:00+00:00
# 3  2020    CA    CDF     NEU   FLEMING  00007619  2020-03-31T00:00:00+00:00
# 4  2020    CA    CDF     NEU  MELANESE  00008471  2020-04-14T00:00:00+00:00
#
#                    CONT_DATE  CAUSE COMMENTS   GIS_ACRES  C_METHOD  OBJECTIVE  \
# 0  2020-06-23T00:00:00+00:00   11.0           109.602280       1.0        1.0
# 1  2020-06-04T00:00:00+00:00    2.0           685.585022       1.0        1.0
# 2  2020-08-11T00:00:00+00:00   14.0            27.300480       1.0        1.0
# 3  2020-04-01T00:00:00+00:00    9.0            12.931545       1.0        1.0
# 4  2020-04-19T00:00:00+00:00   18.0            10.315964       1.0        1.0
#
#   FIRE_NUM COMPLEX_NAME COMPLEX_INCNUM IRWINID  Shape_Length    Shape_Area  \
# 0     None         None           None    None   3252.523280  4.435447e+05
# 1     None         None           None    None   9653.760308  2.774464e+06
# 2     None         None           None    None   1649.643235  1.104811e+05
# 3     None         None           None    None   1577.155857  5.233211e+04
# 4     None         None           None    None   1035.787625  4.174722e+04
#
#                                             geometry
# 0  MULTIPOLYGON (((-121.34841 38.88999, -121.3483...
# 1  MULTIPOLYGON (((-121.35275 38.82039, -121.3526...
# 2  MULTIPOLYGON (((-121.33334 38.84558, -121.3331...
# 3  MULTIPOLYGON (((-121.27317 38.96308, -121.2730...
# 4  MULTIPOLYGON (((-121.30066 39.48714, -121.3004...

# %%
fire_perimeters[fire_perimeters["AGENCY"] == "NPS"]
# Out:
#       YEAR_ STATE AGENCY UNIT_ID  FIRE_NAME   INC_NUM  \
# 276    2020    CA    NPS     MNP       BULL  00013423
# 305    2020    CA    NPS     YNP    BLUEJAY  00000054
# 306    2020    CA    NPS     BNP   CALDWELL  00000479
# 307    2020    CA    NPS     MNP       DOME  00012356
# 308    2020    CA    NPS     YNP      HORSE  00000089
# ...     ...   ...    ...     ...        ...       ...
# 21856  2022    CA    NPS     YNP        RED  00000056
# 21857  2022    CA    NPS     YNP    RODGERS  00000058
# 21858  2022    CA    NPS     KNP  AVALANCHE  00000049
# 21859  2022    CA    NPS     KNP     SUMMIT  00000075
# 21860  2022    CA    NPS     YNP      ASPEN  00000066
#
#                       ALARM_DATE                  CONT_DATE  CAUSE  \
# 276    2020-09-05T00:00:00+00:00  2020-09-05T00:00:00+00:00   10.0
# 305    2020-07-25T00:00:00+00:00  2020-11-19T00:00:00+00:00    1.0
# 306    2020-07-22T00:00:00+00:00  2020-09-01T00:00:00+00:00    1.0
# 307    2020-08-15T00:00:00+00:00  2020-09-12T00:00:00+00:00    1.0
# 308    2020-08-23T00:00:00+00:00  2020-11-19T00:00:00+00:00    1.0
# ...                          ...                        ...    ...
# 21856  2022-08-04T00:00:00+00:00  2022-11-06T00:00:00+00:00    1.0
# 21857  2022-08-08T00:00:00+00:00  2022-11-06T00:00:00+00:00    1.0
# 21858  2022-07-18T00:00:00+00:00  2022-11-10T00:00:00+00:00    1.0
# 21859  2022-08-03T00:00:00+00:00  2022-10-19T00:00:00+00:00    1.0
# 21860  2022-09-04T00:00:00+00:00  2022-09-30T00:00:00+00:00    7.0
#
#                                    COMMENTS     GIS_ACRES  C_METHOD  \
# 276    AFC018BF-96ED-4018-AB90-77E625432EA7     14.089692       8.0
# 305                                           6922.013672       7.0
# 306                                          81224.679688       7.0
# 307             Auto-generated by EGP-IRWIN  44211.250000       8.0
# 308                                             30.192495       1.0
# ...                                     ...           ...       ...
# 21856                                  None   8432.418945       3.0
# 21857                                  None   2839.684082       3.0
# 21858                                  None     28.925026       7.0
# 21859                                  None   1394.439575       7.0
# 21860                                  None     25.892586       3.0
#
#        OBJECTIVE FIRE_NUM COMPLEX_NAME COMPLEX_INCNUM  \
# 276          1.0     None         None           None
# 305          2.0     None         None           None
# 306          1.0     None         None           None
# 307          1.0     None         None           None
# 308          2.0     None         None           None
# ...          ...      ...          ...            ...
# 21856        2.0     None         None           None
# 21857        2.0     None         None           None
# 21858        2.0     None         None           None
# 21859        2.0     None         None           None
# 21860        1.0     None         None           None
#
#                                     IRWINID   Shape_Length    Shape_Area  \
# 276                                    None    1655.085138  5.701896e+04
# 305                                    None   44088.647246  2.801240e+07
# 306                                    None  176044.495381  3.287046e+08
# 307                                    None   76882.528186  1.789166e+08
# 308                                    None    4215.009845  1.221847e+05
# ...                                     ...            ...           ...
# 21856  1E643C3B-3BE4-4669-892B-CF82B46FA820   98931.614579  3.412479e+07
# 21857  99B90DBC-6F1A-4494-B5C6-9CFDF335492A   54091.789770  1.149179e+07
# 21858  52D1B9EC-9479-48E6-AF4A-D1550E8A97CB    1415.510211  1.170554e+05
# 21859  F3705FA2-72E3-4E2A-BBE0-EA04D37FAE54   15630.965622  5.643097e+06
# 21860  B8C14C30-8CC6-404E-A717-BB3992F07F71    1752.206357  1.047836e+05
#
#                                                 geometry
# 276    MULTIPOLYGON (((-115.79681 35.40100, -115.7961...
# 305    MULTIPOLYGON (((-119.60746 37.81324, -119.6074...
# 306    MULTIPOLYGON (((-121.60456 41.83603, -121.6045...
# 307    MULTIPOLYGON (((-115.54279 35.36503, -115.5461...
# 308    MULTIPOLYGON (((-119.53190 37.62689, -119.5319...
# ...                                                  ...
# 21856  MULTIPOLYGON (((-119.48282 37.70949, -119.4828...
# 21857  MULTIPOLYGON (((-119.52391 37.94608, -119.5239...
# 21858  MULTIPOLYGON (((-118.58141 36.77579, -118.5815...
# 21859  MULTIPOLYGON (((-118.66634 36.33272, -118.6663...
# 21860  MULTIPOLYGON (((-119.76521 37.83940, -119.7652...
#
# [1031 rows x 20 columns]

# %% [markdown]
# To batch process (some) of these, we can use our batch endpoint, which accepts all of the form arguments we get from the frontend and does our anaylze and fetch workflows.

# %%
# Create a client
client = tasks_v2.CloudTasksClient()

# Get logger
# logging_client = logging.Client(project="dse-nps")
# log_name = "burn-backend"
# logger = logging_client.logger(log_name)
logger = get_cloud_logger()

# Get cloud static io client
# s3_bucket_name = os.getenv("S3_BUCKET_NAME")
# cloud_static_io_client = CloudStaticIOClient(s3_bucket_name, "s3")
cloud_static_io_client = get_cloud_static_io_client(logger=logger)

# Define our Google Cloud Project ID and Queue ID
project = "dse-nps"
queue = "tf-rest-burn-severity-queue-dev"
location = "us-central1"

# Define the URL endpoint of our cloud function
dev_url = "https://tf-rest-burn-severity-dev-ohi6r6qs2a-uc.a.run.app"
# dev_url = "localhost:5050"
batch_url = dev_url + "/api/batch/analyze-and-fetch"
# Out:
# /opt/conda/envs/burn-severity/lib/python3.10/site-packages/google/auth/_default.py:76: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# /opt/conda/envs/burn-severity/lib/python3.10/site-packages/google/auth/_default.py:76: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# /opt/conda/envs/burn-severity/lib/python3.10/site-packages/google/auth/_default.py:76: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)

# %%
import json
from shapely.geometry import mapping

# Convert DataFrame row to dictionary
def row_to_dict(row):
    return row.to_dict()


# Create a task with row data as payload
def create_task(row):
    # Convert the row to a dictionary
    row_dict = row_to_dict(row)

    coord_list = list(row['geometry'].boundary.convex_hull.exterior.coords)
    bounds = box(*row['geometry'].bounds)

    del row_dict['geometry']

    row_geojson = {
                    "type": "FeatureCollection",
                    "features": [
                        {
                            "id": "0",
                            "type": "Feature",
                            "properties": row_dict,
                            "geometry": {
                                "type": "Polygon",
                                "coordinates": [coord_list]
                            }
                        }
                    ]
                }

    ignition_date = datetime.datetime.strptime(
        row_dict["ALARM_DATE"], "%Y-%m-%dT%H:%M:%S%z"
    )
    containment_date = datetime.datetime.strptime(
        row_dict["CONT_DATE"], "%Y-%m-%dT%H:%M:%S%z"
    )

    post_body = {
        "fire_event_name": row_dict["FIRE_NAME"],
        "affiliation": row_dict["AGENCY"] + "_CalFire",
        "ignition_date": str(ignition_date),
        "containment_date": str(containment_date),
        "time_buffer_days": 30,
        "derive_boundary": False,
        "geojson_boundary": json.dumps(row_geojson),
    }

    # batch_analyze_and_fetch(
    #     geojson_boundary=post_body["geojson_boundary"],
    #     fire_event_name=post_body["fire_event_name"],
    #     affiliation=post_body["affiliation"],
    #     derive_boundary=post_body["derive_boundary"],
    #     logger=logger,
    #     cloud_static_io_client=cloud_static_io_client,
    #     ignition_date=ignition_date,
    #     containment_date=containment_date,
    #     time_buffer_days=post_body["time_buffer_days"],
    # )

    ### FIRST, the boundary as given by calfire
    payload = json.dumps(post_body).encode()

    # ## Hit the local endpoint

    # local_url = "http://localhost:5050/api/batch/analyze-and-fetch"
    # response = requests.post(local_url, data=payload, headers={"Content-type": "application/json"})
    # return response
    # Construct the request body
    parent = f"projects/{project}/locations/{location}/queues/{queue}"
    task = {
        "http_request": {
            "http_method": "POST",
            "url": batch_url,
            "body": payload,
            "headers": {"Content-type": "application/json"},
        }
    }

    # Add the timestamp to the tasks
    timestamp = timestamp_pb2.Timestamp()
    timestamp.FromDatetime(datetime.datetime.utcnow() + datetime.timedelta(seconds=10))
    task["schedule_time"] = timestamp

    # Use the client to build and send the task
    response = client.create_task(request={"parent": parent, "task": task})

    print("Created task {}".format(response.name))

    ### SECOND, the boundary as derived by the simple threshold
    post_body["derive_boundary"] = True
    post_body["fire_event_name"] = post_body["fire_event_name"] + "_derived"

    buffered_bbox = bounds.buffer(0.1)
    buffered_bbox_coords = mapping(buffered_bbox)["coordinates"]

    row_approx_geojson = {
        "type": "FeatureCollection",
        "features": [
            {
                "id": "0",
                "type": "Feature",
                "properties": row_dict,
                "geometry": {"type": "Polygon", "coordinates": buffered_bbox_coords},
            }
        ],
    }
    post_body["geojson_boundary"] = json.dumps(row_approx_geojson)

    payload = json.dumps(post_body).encode()

    # Construct the request body
    parent = f"projects/{project}/locations/{location}/queues/{queue}"
    task = {
        "http_request": {
            "http_method": "POST",
            "url": batch_url,
            "body": payload,
            "headers": {"Content-type": "application/json"},
        }
    }

    # Add the timestamp to the tasks
    timestamp = timestamp_pb2.Timestamp()
    timestamp.FromDatetime(datetime.datetime.utcnow() + datetime.timedelta(seconds=10))
    task["schedule_time"] = timestamp

    # Use the client to build and send the task
    response = client.create_task(request={"parent": parent, "task": task})

    print("Created task {}".format(response.name))

# %% [markdown]
# For our test, we want Southern CA fires during Sentinel 2's time:

# %%
lat_min = 32
lon_min = -120
lat_max = 37
lon_max = -115

# make into a polygon geopandas for sjoin
bbox = box(lon_min, lat_min, lon_max, lat_max)
bbox_gdf = gpd.GeoDataFrame(geometry=[bbox], crs="EPSG:4326")
bbox_gdf
# Out:
#                                             geometry
# 0  POLYGON ((-115.00000 32.00000, -115.00000 37.0...

# %%
bbox.bounds
# Out:
# (-120.0, 32.0, -115.0, 37.0)

# %%
from geopandas.tools import sjoin
sample_fire_perimeter = sjoin(fire_perimeters, bbox_gdf, how="inner")
sample_fire_perimeter = sample_fire_perimeter[sample_fire_perimeter["YEAR_"] != '']
sample_fire_perimeter["YEAR_"] = sample_fire_perimeter["YEAR_"].astype("int")
nps_fires = sample_fire_perimeter[(sample_fire_perimeter["YEAR_"] > 2015) & (sample_fire_perimeter["AGENCY"] == "NPS")]

# %%
nps_fires
# Out:
#        YEAR_ STATE AGENCY UNIT_ID       FIRE_NAME   INC_NUM  \
# 276     2020    CA    NPS     MNP            BULL  00013423
# 307     2020    CA    NPS     MNP            DOME  00012356
# 309     2020    CA    NPS     MNP         IVANPAH  00009202
# 310     2020    CA    NPS     KNP         MORAINE  00000091
# 312     2020    CA    NPS     KNP     RATTLESNAKE  00000080
# 313     2020    CA    NPS     CNP        SCORPION  00001216
# 12374   2016    CA    NPS     SMP           COAST    000896
# 12375   2016    CA    NPS     SMP  LIBERTY CANYON    000843
# 12376   2016    CA    NPS     SMP      MULHOLLAND    000210
# 12377   2016    CA    NPS     KNP           YUCCA    000184
# 12378   2016    CA    NPS     KNP        SENTINEL    000140
# 20405   2017    CA    NPS     KNP     NORTH GUARD  00000073
# 20417   2017    CA    NPS     MNP       FORD LAKE  00010693
# 20418   2017    CA    NPS     MNP         GRANITE  00010636
# 20817   2018    CA    NPS     CNP      SANTA CRUZ
# 20818   2018    CA    NPS     KNP            EDEN
# 20819   2018    CA    NPS     SMP           SERRA
# 20820   2018    CA    NPS     KNP          THARPS
# 20821   2018    CA    NPS     KNP        DENNISON
# 20822   2018    CA    NPS     SMP          KNOLLS
# 20824   2018    CA    NPS     KNP     HORSE CREEK
# 20826   2018    CA    NPS     SMP         CORNELL
# 20827   2018    CA    NPS     KNP     NORTH BUBBS
# 21149   2019    CA    NPS     SMP           WENDY  00000558
# 21150   2019    CA    NPS     MNP            STAR  00013598
# 21284   2021    CA    NPS     MNP          CASTLE  00004963
# 21295   2021    CA    NPS     MNP            HART  00012953
# 21300   2021    CA    NPS     KNP        SENTINEL  00000077
# 21302   2021    CA    NPS     KNP            LOST  00000053
# 21306   2021    CA    NPS     MNP            POND  00012915
# 21309   2021    CA    NPS     MNP          MOJAVE  00009642
# 21310   2021    CA    NPS     KNP     KNP Complex  00000122
# 21854   2022    CA    NPS     JTP       ELK TRAIL  00008459
# 21858   2022    CA    NPS     KNP       AVALANCHE  00000049
# 21859   2022    CA    NPS     KNP          SUMMIT  00000075
#
#                       ALARM_DATE                  CONT_DATE  CAUSE  \
# 276    2020-09-05T00:00:00+00:00  2020-09-05T00:00:00+00:00   10.0
# 307    2020-08-15T00:00:00+00:00  2020-09-12T00:00:00+00:00    1.0
# 309    2020-06-22T00:00:00+00:00  2020-06-26T00:00:00+00:00    8.0
# 310    2020-08-21T00:00:00+00:00  2020-12-29T00:00:00+00:00    1.0
# 312    2020-08-16T00:00:00+00:00  2020-12-28T00:00:00+00:00    1.0
# 313    2020-05-31T00:00:00+00:00  2020-06-05T00:00:00+00:00    2.0
# 12374  2016-12-02T00:00:00+00:00  2016-12-02T00:00:00+00:00   14.0
# 12375  2016-11-05T00:00:00+00:00  2016-11-05T00:00:00+00:00   14.0
# 12376  2016-02-25T00:00:00+00:00  2016-02-28T00:00:00+00:00   14.0
# 12377  2016-11-05T00:00:00+00:00  2016-11-15T00:00:00+00:00    1.0
# 12378  2016-08-19T00:00:00+00:00  2016-11-15T00:00:00+00:00    1.0
# 20405  2017-07-18T00:00:00+00:00  2017-11-27T00:00:00+00:00    1.0
# 20417  2017-07-10T00:00:00+00:00  2017-07-11T00:00:00+00:00    1.0
# 20418  2017-07-08T00:00:00+00:00  2017-07-11T00:00:00+00:00    1.0
# 20817  2018-03-27T00:00:00+00:00  2018-04-05T00:00:00+00:00   18.0
# 20818  2018-10-04T00:00:00+00:00  2018-12-04T00:00:00+00:00    1.0
# 20819  2018-01-29T00:00:00+00:00  2018-01-30T00:00:00+00:00   14.0
# 20820  2018-10-12T00:00:00+00:00  2018-11-28T00:00:00+00:00    1.0
# 20821  2018-10-13T00:00:00+00:00  2018-12-04T00:00:00+00:00    1.0
# 20822  2018-10-19T00:00:00+00:00  2018-10-20T00:00:00+00:00    4.0
# 20824  2018-07-19T00:00:00+00:00  2018-09-06T00:00:00+00:00    1.0
# 20826  2018-05-29T00:00:00+00:00  2018-05-30T00:00:00+00:00   14.0
# 20827  2018-08-01T00:00:00+00:00  2018-09-06T00:00:00+00:00    1.0
# 21149  2019-10-10T00:00:00+00:00  2019-10-14T00:00:00+00:00   14.0
# 21150                       None                       None   14.0
# 21284  2021-03-19T00:00:00+00:00  2021-03-21T00:00:00+00:00    4.0
# 21295  2021-08-31T00:00:00+00:00  2021-09-04T00:00:00+00:00    1.0
# 21300  2021-07-29T00:00:00+00:00  2021-10-25T00:00:00+00:00    1.0
# 21302  2021-07-10T00:00:00+00:00  2021-07-18T00:00:00+00:00    1.0
# 21306  2021-08-30T00:00:00+00:00  2021-09-04T00:00:00+00:00    1.0
# 21309  2021-06-17T00:00:00+00:00  2021-06-25T00:00:00+00:00    1.0
# 21310  2021-09-10T00:00:00+00:00  2021-12-16T00:00:00+00:00    1.0
# 21854  2022-05-26T00:00:00+00:00  2022-05-31T00:00:00+00:00    7.0
# 21858  2022-07-18T00:00:00+00:00  2022-11-10T00:00:00+00:00    1.0
# 21859  2022-08-03T00:00:00+00:00  2022-10-19T00:00:00+00:00    1.0
#
#                                                 COMMENTS  ...  C_METHOD  \
# 276                 AFC018BF-96ED-4018-AB90-77E625432EA7  ...       8.0
# 307                          Auto-generated by EGP-IRWIN  ...       8.0
# 309                          Auto-generated by EGP-IRWIN  ...       8.0
# 310                                                       ...       2.0
# 312        estimate based on satellite heat since 21 NOV  ...       7.0
# 313                                                       ...       1.0
# 12374                                               None  ...       8.0
# 12375                                               None  ...       8.0
# 12376                                LA Co. INC # 058094  ...       8.0
# 12377                                         Yucca 2016  ...       8.0
# 12378                                           Sentinel  ...       8.0
# 20405                                               None  ...       2.0
# 20417                                               None  ...       1.0
# 20418                                               None  ...       1.0
# 20817                                       on TNC lands  ...       1.0
# 20818                                  Eden 2018CAKNP-16  ...       5.0
# 20819  Serra 1/29/2018, LACFD reported 2acres. Some s...  ...       8.0
# 20820                                Tharps 2018CAKNP-17  ...       1.0
# 20821                              Dennison 2018CAKNP-17  ...       5.0
# 20822  Knolls 10/19/2018 0046hr, Campfire = cooking f...  ...       8.0
# 20824                           Horse Creek 2018CAKNP-85  ...       7.0
# 20826  Cornell 5/29/2018 1400hr, Equipment, cause = N...  ...       8.0
# 20827                           North Bubbs 2018CAKNP-10  ...       7.0
# 21149               FRA Supression by VCFD County #82061  ...       1.0
# 21150                                               None  ...       8.0
# 21284                                               None  ...       7.0
# 21295                                               None  ...       1.0
# 21300                                               None  ...       2.0
# 21302                                               None  ...       1.0
# 21306                                               None  ...       1.0
# 21309                                               None  ...       1.0
# 21310  Includes Paradise (INC #00000116) and Colony (...  ...       7.0
# 21854                                               None  ...       1.0
# 21858                                               None  ...       7.0
# 21859                                               None  ...       7.0
#
#        OBJECTIVE  FIRE_NUM COMPLEX_NAME COMPLEX_INCNUM  \
# 276          1.0      None         None           None
# 307          1.0      None         None           None
# 309          1.0      None         None           None
# 310          1.0      None         None           None
# 312          2.0      None         None           None
# 313          1.0      None         None           None
# 12374        1.0      None         None           None
# 12375        1.0      None         None           None
# 12376        1.0      None         None           None
# 12377        1.0      None         None           None
# 12378        1.0      None         None           None
# 20405        1.0        73         None           None
# 20417        1.0     10693         None           None
# 20418        1.0     10636         None           None
# 20817        1.0      None         None           None
# 20818        1.0      None         None           None
# 20819        1.0      None         None           None
# 20820        1.0      None         None           None
# 20821        1.0      None         None           None
# 20822        1.0      None         None           None
# 20824        1.0      None         None           None
# 20826        1.0      None         None           None
# 20827        1.0      None         None           None
# 21149        1.0      None         None           None
# 21150        1.0      None         None           None
# 21284        1.0      None         None           None
# 21295        1.0      None         None           None
# 21300        1.0      None         None           None
# 21302        1.0      None         None           None
# 21306        1.0      None         None           None
# 21309        1.0      None         None           None
# 21310        1.0      None         None           None
# 21854        1.0      None         None           None
# 21858        2.0      None         None           None
# 21859        2.0      None         None           None
#
#                                     IRWINID   Shape_Length    Shape_Area  \
# 276                                    None    1655.085138  5.701896e+04
# 307                                    None   76882.528186  1.789166e+08
# 309                                    None   10036.750481  4.255211e+06
# 310                                    None   12433.665515  5.325816e+06
# 312                                    None  114391.760771  3.408614e+07
# 313                                    None   23541.766224  5.344798e+06
# 12374                                  None     461.384327  4.724250e+03
# 12375                                  None      63.357001  3.145807e+02
# 12376                                  None    1032.685562  4.583182e+04
# 12377                                  None    4271.848972  2.901110e+05
# 12378                                  None    2545.104953  3.009994e+05
# 20405                                  None    1124.766806  3.332926e+04
# 20417                                  None    1316.776231  1.520497e+04
# 20418                                  None     805.956650  1.852919e+04
# 20817                                  None   14855.550719  1.045902e+06
# 20818                                  None   12756.326577  7.193673e+06
# 20819                                  None     672.669313  1.052408e+04
# 20820                                  None     666.358526  5.520517e+03
# 20821                                  None    3304.789441  3.523791e+05
# 20822                                  None     393.037517  4.911609e+03
# 20824                                  None    2913.368737  1.396831e+05
# 20826                                  None     246.266577  3.536738e+03
# 20827                                  None    5018.227481  7.021907e+05
# 21149                                  None    3046.560697  3.250747e+05
# 21150                                  None    3897.065019  2.694688e+05
# 21284                                  None    1194.302524  2.078476e+04
# 21295                                  None    1210.687582  2.646527e+04
# 21300                                  None    1147.855738  5.054322e+04
# 21302                                  None    5788.053699  4.078521e+05
# 21306                                  None    6803.240393  1.985935e+06
# 21309                                  None   28314.280468  1.007869e+07
# 21310                                  None  393692.892389  3.571639e+08
# 21854  6560BC7F-50C4-4990-9555-C1EA10FDCEC1   11266.861900  1.675847e+06
# 21858  52D1B9EC-9479-48E6-AF4A-D1550E8A97CB    1415.510211  1.170554e+05
# 21859  F3705FA2-72E3-4E2A-BBE0-EA04D37FAE54   15630.965622  5.643097e+06
#
#                                                 geometry index_right
# 276    MULTIPOLYGON (((-115.79681 35.40100, -115.7961...           0
# 307    MULTIPOLYGON (((-115.54279 35.36503, -115.5461...           0
# 309    MULTIPOLYGON (((-115.17324 35.19340, -115.1734...           0
# 310    MULTIPOLYGON (((-118.56183 36.72931, -118.5617...           0
# 312    MULTIPOLYGON (((-118.40697 36.36010, -118.4073...           0
# 313    MULTIPOLYGON (((-119.55486 34.04815, -119.5538...           0
# 12374  MULTIPOLYGON (((-118.94804 34.04749, -118.9480...           0
# 12375  MULTIPOLYGON (((-118.72723 34.13779, -118.7272...           0
# 12376  MULTIPOLYGON (((-118.91151 34.08538, -118.9115...           0
# 12377  MULTIPOLYGON (((-118.85826 36.60500, -118.8583...           0
# 12378  MULTIPOLYGON (((-118.70200 36.74965, -118.7015...           0
# 20405  MULTIPOLYGON (((-118.47320 36.75907, -118.4732...           0
# 20417  MULTIPOLYGON (((-115.26735 35.06080, -115.2672...           0
# 20418  MULTIPOLYGON (((-115.66049 34.79612, -115.6604...           0
# 20817  MULTIPOLYGON (((-119.70752 33.99512, -119.7075...           0
# 20818  MULTIPOLYGON (((-118.73719 36.41339, -118.7369...           0
# 20819  MULTIPOLYGON (((-118.68968 34.04059, -118.6896...           0
# 20820  MULTIPOLYGON (((-118.74047 36.56266, -118.7404...           0
# 20821  MULTIPOLYGON (((-118.68501 36.32036, -118.6851...           0
# 20822  MULTIPOLYGON (((-118.69667 34.04198, -118.6966...           0
# 20824  MULTIPOLYGON (((-118.70537 36.42835, -118.7053...           0
# 20826  MULTIPOLYGON (((-118.75066 34.11988, -118.7506...           0
# 20827  MULTIPOLYGON (((-118.54127 36.78161, -118.5415...           0
# 21149  MULTIPOLYGON (((-118.96365 34.14729, -118.9635...           0
# 21150  MULTIPOLYGON (((-115.49858 35.26826, -115.4986...           0
# 21284  MULTIPOLYGON (((-115.09810 35.32324, -115.0982...           0
# 21295  MULTIPOLYGON (((-115.23144 35.20666, -115.2314...           0
# 21300  MULTIPOLYGON (((-118.67007 36.75236, -118.6701...           0
# 21302  MULTIPOLYGON (((-118.69804 36.92070, -118.6981...           0
# 21306  MULTIPOLYGON (((-115.16231 35.26495, -115.1620...           0
# 21309  MULTIPOLYGON (((-115.73741 35.36123, -115.7372...           0
# 21310  MULTIPOLYGON (((-118.75189 36.42762, -118.7525...           0
# 21854  MULTIPOLYGON (((-116.44054 34.08607, -116.4404...           0
# 21858  MULTIPOLYGON (((-118.58141 36.77579, -118.5815...           0
# 21859  MULTIPOLYGON (((-118.66634 36.33272, -118.6663...           0
#
# [35 rows x 21 columns]

# %%
for index, row in nps_fires.iterrows():
    create_task(row)
# Out:
# Created task projects/dse-nps/locations/us-central1/queues/tf-rest-burn-severity-queue-dev/tasks/84070019243162664341
